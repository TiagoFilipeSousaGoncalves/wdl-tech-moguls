# %%
from pandas_ods_reader import read_ods
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

#unemployment dataframe creation for sep 2019 - Feb 2020
mes=['setembro','outubro','novembro','dezembro','Janeiro','fevereiro']
dfn=[]
for idx,i in enumerate(mes):
    if i=='setembro'or i=='outubro' or i=='novembro'or i=='dezembro':
        ano=2019
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 4
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,3,300])
        df = df.drop(columns=["unnamed.2","unnamed.8","unnamed.9","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': 'homens_desempregados', 'unnamed.6': 'mulheres_desempregadas', 'unnamed.7': 'total_desempregados'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)
    else:
        ano=2020
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 4
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,3,300])
        df = df.drop(columns=["unnamed.2","unnamed.8","unnamed.9","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': 'homens_desempregados', 'unnamed.6': 'mulheres_desempregadas', 'unnamed.7': 'total_desempregados'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)

        
df_final=pd.concat(dfn[i] for i in range(6))
df_final['homens_desempregados'] = df_final['homens_desempregados'].astype(float)
df_final['mulheres_desempregadas'] = df_final['mulheres_desempregadas'].astype(float)
df_final['total_desempregados'] = df_final['total_desempregados'].astype(float)
df_desemprego_1=df_final.groupby(['concelhos']).mean().astype(int).reset_index()


#unemployment dataframe creation for sep 2020 - January 2021
mes=['setembro','outubro','novembro','dezembro','Janeiro']
dfn=[]
for idx,i in enumerate(mes):
    if i=='setembro'or i=='outubro' or i=='novembro'or i=='dezembro':
        ano=2020
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 4
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,3,300])
        df = df.drop(columns=["unnamed.2","unnamed.8","unnamed.9","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': 'homens_desempregados', 'unnamed.6': 'mulheres_desempregadas', 'unnamed.7': 'total_desempregados'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)
    else:
        ano=2021
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 4
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,3,300])
        df = df.drop(columns=["unnamed.2","unnamed.8","unnamed.9","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': 'homens_desempregados', 'unnamed.6': 'mulheres_desempregadas', 'unnamed.7': 'total_desempregados'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)

df_final=pd.concat(dfn[i] for i in range(5))
df_final['homens_desempregados'] = df_final['homens_desempregados'].astype(float)
df_final['mulheres_desempregadas'] = df_final['mulheres_desempregadas'].astype(float)
df_final['total_desempregados'] = df_final['total_desempregados'].astype(float)
df_desemprego_2=df_final.groupby(['concelhos']).mean().astype(int).reset_index()

# %%
# Load churn dataset

churn_od = pd.read_csv('Churn_OD.txt', delimiter = "|", encoding= 'unicode_escape')
churn_user_profile = pd.read_csv('Churn_UsersProfile.txt', delimiter = "|", encoding= 'unicode_escape')
county=churn_od['County_of_Public_Transportation'].str.lower()

# %%
#test new dataframe
ind=df_desemprego_1[df_desemprego_1['concelhos']=='porto']
ind
# Out:
#     concelhos  < 25 Anos  25 - 34 Anos  35 - 54 Anos  55 Anos e +  TOTAL
# 194     porto        636          1789          4247         3143   9817

# %%
df_1=df_desemprego_1[df_desemprego_1['concelhos'].isin(county.unique())]
print('Sept 2019 - February 2020')
print(df_1.sum(axis = 0, skipna = True))
df_1
# Out:
# Sept 2019 - February 2020
# concelhos                 almadaamadoragondomarlisboalouresmaiamatosinho...
# homens_desempregados                                                   6675
# mulheres_desempregadas                                                 7799
# total_desempregados                                                   14483
# dtype: object
#              concelhos  homens_desempregados  mulheres_desempregadas  \
# 15              almada                   317                     397
# 23             amadora                   300                     367
# 100           gondomar                   449                     488
# 111             lisboa                  1033                    1099
# 113             loures                   350                     416
# 119               maia                   279                     363
# 125         matosinhos                   425                     407
# 157           odivelas                   259                     309
# ...

# %%
df_2=df_desemprego_2[df_desemprego_2['concelhos'].isin(county.unique())]
print('Sept 2020 - January 2020')
print(df_2.sum(axis = 0, skipna = True))
df_2
# Out:
# Sept 2020 - January 2020
# concelhos                 almadaamadoragondomarlisboalouresmaiamatosinho...
# homens_desempregados                                                   7601
# mulheres_desempregadas                                                 8752
# total_desempregados                                                   16361
# dtype: object
#              concelhos  homens_desempregados  mulheres_desempregadas  \
# 15              almada                   381                     456
# 23             amadora                   389                     449
# 100           gondomar                   383                     433
# 111             lisboa                  1407                    1326
# 113             loures                   407                     476
# 119               maia                   315                     394
# 125         matosinhos                   448                     473
# 157           odivelas                   341                     376
# ...

# %%
#dados de desemprego por idade

# %%
mes=['setembro','outubro','novembro','dezembro','Janeiro','fevereiro']
dfn=[]
for idx,i in enumerate(mes):
    if i=='setembro'or i=='outubro' or i=='novembro'or i=='dezembro':
        ano=2019
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 2
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,285,287])
        df = df.drop(columns=["unnamed.2","unnamed.3","unnamed.6","unnamed.8","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': '< 25 Anos', 'unnamed.7': '25 - 34 Anos', 'unnamed.9': '35 - 54 Anos', 'unnamed.11': '55 Anos e +', 'unnamed.12': 'TOTAL'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)
    else:
        ano=2020
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 2
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,285,287])
        df = df.drop(columns=["unnamed.2","unnamed.3","unnamed.6","unnamed.8","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': '< 25 Anos', 'unnamed.7': '25 - 34 Anos', 'unnamed.9': '35 - 54 Anos', 'unnamed.11': '55 Anos e +', 'unnamed.12': 'TOTAL'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)

df_final=pd.concat(dfn[i] for i in range(6))
df_final['< 25 Anos'] = df_final['< 25 Anos'].astype(float)
df_final['25 - 34 Anos'] = df_final['25 - 34 Anos'].astype(float)
df_final['35 - 54 Anos'] = df_final['35 - 54 Anos'].astype(float)
df_final['55 Anos e +'] = df_final['55 Anos e +'].astype(float)
df_final['TOTAL'] = df_final['TOTAL'].astype(float)
df_desemprego_1=df_final.groupby(['concelhos']).mean().astype(int).reset_index()
df_desemprego_1

df_1=df_desemprego_1[df_desemprego_1['concelhos'].isin(county.unique())].reset_index()
df_1
# Out:
#     index          concelhos  < 25 Anos  25 - 34 Anos  35 - 54 Anos  \
# 0      16             almada        322           890          2220
# 1      24            amadora        390           868          1686
# 2     102           gondomar        683          1113          2517
# 3     113             lisboa       1132          2869          6826
# 4     116             loures        464          1035          2132
# 5     122               maia        356           634          1640
# 6     128         matosinhos        483           987          2636
# 7     161           odivelas        209           552          1349
# 8     162             oeiras        230           569          1681
# 9     174            paredes        333           467          1193
# 10    194              porto        636          1789          4247
# 11    212        santo tirso        227           316           936
# 12    215             seixal        435           846          1789
# ...

# %%
#unemployment dataframe creation for sep 2020 - January 2021
mes=['setembro','outubro','novembro','dezembro','Janeiro']
dfn=[]
for idx,i in enumerate(mes):
    if i=='setembro'or i=='outubro' or i=='novembro'or i=='dezembro':
        ano=2020
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 2
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,285,287])
        df = df.drop(columns=["unnamed.2","unnamed.3","unnamed.6","unnamed.8","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': '< 25 Anos', 'unnamed.7': '25 - 34 Anos', 'unnamed.9': '35 - 54 Anos', 'unnamed.11': '55 Anos e +', 'unnamed.12': 'TOTAL'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)
    else:
        ano=2021
        path = "dados_iefp/SIE - Desemprego registado por concelhos %s %d.ods" %(i,ano)
        # Data cleaning
        sheet_idx = 2
        df = read_ods(path, sheet_idx)
        df=df.drop([0,1,2,285,287])
        df = df.drop(columns=["unnamed.2","unnamed.3","unnamed.6","unnamed.8","unnamed.10"])
        df = df.rename(columns = {'unnamed.4': 'concelhos', 'unnamed.5': '< 25 Anos', 'unnamed.7': '25 - 34 Anos', 'unnamed.9': '35 - 54 Anos', 'unnamed.11': '55 Anos e +', 'unnamed.12': 'TOTAL'}, inplace = False)
        df['concelhos']=df['concelhos'].str.lower()
        df=df.dropna()
        dfn.append(df)

df_final=pd.concat(dfn[i] for i in range(4))
df_final['< 25 Anos'] = df_final['< 25 Anos'].astype(float)
df_final['25 - 34 Anos'] = df_final['25 - 34 Anos'].astype(float)
df_final['35 - 54 Anos'] = df_final['35 - 54 Anos'].astype(float)
df_final['55 Anos e +'] = df_final['55 Anos e +'].astype(float)
df_final['TOTAL'] = df_final['TOTAL'].astype(float)

df_desemprego_2=df_final.groupby(['concelhos']).mean().astype(int).reset_index()

df_desemprego_2


df_2=df_desemprego_2[df_desemprego_2['concelhos'].isin(county.unique())].reset_index()
df_2
# Out:
#     index          concelhos  < 25 Anos  25 - 34 Anos  35 - 54 Anos  \
# 0      16             almada        630          1592          3017
# 1      24            amadora        884          1933          2678
# 2     102           gondomar       1130          1650          3319
# 3     113             lisboa       2280          5663          9202
# 4     116             loures        955          2022          3486
# 5     122               maia        601           980          2191
# 6     128         matosinhos        729          1450          3126
# 7     161           odivelas        684          1400          2453
# 8     162             oeiras        530          1158          2505
# 9     174            paredes        454           611          1495
# 10    194              porto       1016          2651          5202
# 11    212        santo tirso        306           412           997
# 12    215             seixal        727          1467          2576
# ...
